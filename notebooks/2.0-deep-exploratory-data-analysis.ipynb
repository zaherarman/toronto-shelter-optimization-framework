# %%
import os
import requests
from datetime import datetime
from typing import List, Dict
import logging
import regex as re

import time
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
df
# Out:
#                  date_time                     shelter_name  \
# 0      2017-01-01 04:00:00           COSTI Reception Centre
# 1      2017-01-01 04:00:00  Christie Ossington Men's Hostel
# 2      2017-01-01 04:00:00  Christie Ossington Men's Hostel
# 3      2017-01-01 04:00:00  Christie Refugee Welcome Centre
# 4      2017-01-01 04:00:00               Birkdale Residence
# ...                    ...                              ...
# 388713 2025-10-28 04:00:00           YWCA Davenport Shelter
# 388714 2025-10-28 04:00:00           Youth Without Shelter
# 388715 2025-10-28 04:00:00           Youth Without Shelter
# 388716 2025-10-28 04:00:00                       YouthLink
# 388717 2025-10-28 04:00:00                       YouthLink
#
#                                              program_name    sector  \
# 0                        COSTI Reception Ctr CITY Program     Co-ed
# 1              Christie Ossington Extreme Weather Program       Men
# 2                         Christie Ossington Men's Hostel       Men
# 3       Christie Refugee Welcome Ctr - Settlement and ...  Families
# 4                     Birkdale Residence - Bedded Program  Families
# ...                                                   ...       ...
# 388713                             YWCA Davenport - Youth     Youth
# 388714    Youth without Shelter Emergency Shelter Program     Youth
# 388715       Youth without Shelter Stay In School Program     Youth
# 388716                        YouthLink Emergency Program     Youth
# 388717                     YouthLink Transitional Program     Youth
#
#               shelter_address shelter_city shelter_postal_code data_schema  \
# 0       100 Lippincott Street      Toronto             M5S 2P1    pre_2021
# 1        973 Lansdowne Avenue      Toronto             M6H 3Z5    pre_2021
# 2        973 Lansdowne Avenue      Toronto             M6H 3Z5    pre_2021
# 3          43 Christie Street      Toronto             M6G 3B1    pre_2021
# 4         1229 Ellesmere Road      Toronto             M1P 4V8    pre_2021
# ...                       ...          ...                 ...         ...
# 388713     348 Davenport Road      Toronto             M5R 1K6   post_2021
# 388714        6 Warrendale Ct    Etobicoke             M9V 1P9   post_2021
# 388715        6 Warrendale Ct    Etobicoke             M9V 1P9   post_2021
# 388716         747 Warden Ave  Scarborough             M1L 4A1   post_2021
# 388717         747 Warden Ave  Scarborough             M1L 4A1   post_2021
#
#         year       capacity_type  capacity_combined  occupancy_combined  \
# 0       2017  Bed Based Capacity               16.0                16.0
# 1       2017  Bed Based Capacity               17.0                13.0
# 2       2017  Bed Based Capacity               63.0                63.0
# 3       2017  Bed Based Capacity               70.0                66.0
# 4       2017  Bed Based Capacity              160.0               168.0
# ...      ...                 ...                ...                 ...
# 388713  2025  Bed Based Capacity               26.0                25.0
# 388714  2025  Bed Based Capacity               33.0                33.0
# 388715  2025  Bed Based Capacity               20.0                20.0
# 388716  2025  Bed Based Capacity               10.0                10.0
# 388717  2025  Bed Based Capacity               41.0                37.0
#
#         occupancy_rate_combined  month  day  weekday  is_weekend        lat  \
# 0                      1.000000      1    1   Sunday        True  43.657562
# 1                      0.764706      1    1   Sunday        True  43.666104
# 2                      1.000000      1    1   Sunday        True  43.666104
# 3                      0.942857      1    1   Sunday        True  43.665203
# 4                      1.050000      1    1   Sunday        True  43.768282
# ...                         ...    ...  ...      ...         ...        ...
# 388713                 0.961538     10   28  Tuesday       False  43.675412
# 388714                 1.000000     10   28  Tuesday       False  43.736310
# 388715                 1.000000     10   28  Tuesday       False  43.736310
# 388716                 1.000000     10   28  Tuesday       False  43.717903
# 388717                 0.902439     10   28  Tuesday       False  43.717903
#
#               lon
# 0      -79.407393
# 1      -79.446019
# 2      -79.446019
# 3      -79.418857
# 4      -79.267447
# ...           ...
# 388713 -79.401333
# 388714 -79.580404
# 388715 -79.580404
# 388716 -79.282891
# 388717 -79.282891
#
# [388718 rows x 19 columns]

# %%
import requests
address = "973 Lansdowne Avenue, Toronto, ON, Canada"

r = requests.get("https://maps.googleapis.com/maps/api/geocode/json",
                 params={"address": address, "key": google_api_key})
print(r.json())
# Out:
# {'results': [{'address_components': [{'long_name': '973', 'short_name': '973', 'types': ['street_number']}, {'long_name': 'Lansdowne Avenue', 'short_name': 'Lansdowne Ave', 'types': ['route']}, {'long_name': 'Old Toronto', 'short_name': 'Old Toronto', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Toronto', 'short_name': 'Toronto', 'types': ['locality', 'political']}, {'long_name': 'Toronto', 'short_name': 'Toronto', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Toronto', 'short_name': 'Toronto', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Ontario', 'short_name': 'ON', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Canada', 'short_name': 'CA', 'types': ['country', 'political']}, {'long_name': 'M6H 3Z5', 'short_name': 'M6H 3Z5', 'types': ['postal_code']}], 'formatted_address': '973 Lansdowne Ave, Toronto, ON M6H 3Z5, Canada', 'geometry': {'bounds': {'northeast': {'lat': 43.6662609, 'lng': -79.4459121}, 'southwest': {'lat': 43.66596089999999, 'lng': -79.44613}}, 'location': {'lat': 43.6661036, 'lng': -79.4460191}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 43.6674598802915, 'lng': -79.4447067697085}, 'southwest': {'lat': 43.6647619197085, 'lng': -79.44740473029151}}}, 'navigation_points': [{'location': {'latitude': 43.666113, 'longitude': -79.4461157}}], 'place_id': 'ChIJHTyf7mo0K4gRx46F5_PrMvY', 'types': ['premise', 'street_address']}], 'status': 'OK'}

# %%
df['lat'] = pd.to_numeric(df['lat'], errors='coerce')
df['lon'] = pd.to_numeric(df['lon'], errors='coerce')
df = df.dropna(subset=['lat', 'lon'])
gdf = gpd.GeoDataFrame(
    df,
    geometry=gpd.points_from_xy(df['lon'], df['lat']),
    crs="EPSG:4326"
)

# %%
gdf
# Out:
#                  date_time                     shelter_name  \
# 0      2017-01-01 04:00:00           COSTI Reception Centre
# 1      2017-01-01 04:00:00  Christie Ossington Men's Hostel
# 2      2017-01-01 04:00:00  Christie Ossington Men's Hostel
# 3      2017-01-01 04:00:00  Christie Refugee Welcome Centre
# 4      2017-01-01 04:00:00               Birkdale Residence
# ...                    ...                              ...
# 388713 2025-10-28 04:00:00           YWCA Davenport Shelter
# 388714 2025-10-28 04:00:00           Youth Without Shelter
# 388715 2025-10-28 04:00:00           Youth Without Shelter
# 388716 2025-10-28 04:00:00                       YouthLink
# 388717 2025-10-28 04:00:00                       YouthLink
#
#                                              program_name    sector  \
# 0                        COSTI Reception Ctr CITY Program     Co-ed
# 1              Christie Ossington Extreme Weather Program       Men
# 2                         Christie Ossington Men's Hostel       Men
# 3       Christie Refugee Welcome Ctr - Settlement and ...  Families
# 4                     Birkdale Residence - Bedded Program  Families
# ...                                                   ...       ...
# 388713                             YWCA Davenport - Youth     Youth
# 388714    Youth without Shelter Emergency Shelter Program     Youth
# 388715       Youth without Shelter Stay In School Program     Youth
# 388716                        YouthLink Emergency Program     Youth
# 388717                     YouthLink Transitional Program     Youth
#
#               shelter_address shelter_city shelter_postal_code data_schema  \
# 0       100 Lippincott Street      Toronto             M5S 2P1    pre_2021
# 1        973 Lansdowne Avenue      Toronto             M6H 3Z5    pre_2021
# 2        973 Lansdowne Avenue      Toronto             M6H 3Z5    pre_2021
# 3          43 Christie Street      Toronto             M6G 3B1    pre_2021
# 4         1229 Ellesmere Road      Toronto             M1P 4V8    pre_2021
# ...                       ...          ...                 ...         ...
# 388713     348 Davenport Road      Toronto             M5R 1K6   post_2021
# 388714        6 Warrendale Ct    Etobicoke             M9V 1P9   post_2021
# 388715        6 Warrendale Ct    Etobicoke             M9V 1P9   post_2021
# 388716         747 Warden Ave  Scarborough             M1L 4A1   post_2021
# 388717         747 Warden Ave  Scarborough             M1L 4A1   post_2021
#
#         year       capacity_type  capacity_combined  occupancy_combined  \
# 0       2017  Bed Based Capacity               16.0                16.0
# 1       2017  Bed Based Capacity               17.0                13.0
# 2       2017  Bed Based Capacity               63.0                63.0
# 3       2017  Bed Based Capacity               70.0                66.0
# 4       2017  Bed Based Capacity              160.0               168.0
# ...      ...                 ...                ...                 ...
# 388713  2025  Bed Based Capacity               26.0                25.0
# 388714  2025  Bed Based Capacity               33.0                33.0
# 388715  2025  Bed Based Capacity               20.0                20.0
# 388716  2025  Bed Based Capacity               10.0                10.0
# 388717  2025  Bed Based Capacity               41.0                37.0
#
#         occupancy_rate_combined  month  day  weekday  is_weekend        lat  \
# 0                      1.000000      1    1   Sunday        True  43.657562
# 1                      0.764706      1    1   Sunday        True  43.666104
# 2                      1.000000      1    1   Sunday        True  43.666104
# 3                      0.942857      1    1   Sunday        True  43.665203
# 4                      1.050000      1    1   Sunday        True  43.768282
# ...                         ...    ...  ...      ...         ...        ...
# 388713                 0.961538     10   28  Tuesday       False  43.675412
# 388714                 1.000000     10   28  Tuesday       False  43.736310
# 388715                 1.000000     10   28  Tuesday       False  43.736310
# 388716                 1.000000     10   28  Tuesday       False  43.717903
# 388717                 0.902439     10   28  Tuesday       False  43.717903
#
#               lon                    geometry
# 0      -79.407393  POINT (-79.40739 43.65756)
# 1      -79.446019   POINT (-79.44602 43.6661)
# 2      -79.446019   POINT (-79.44602 43.6661)
# 3      -79.418857   POINT (-79.41886 43.6652)
# 4      -79.267447  POINT (-79.26745 43.76828)
# ...           ...                         ...
# 388713 -79.401333  POINT (-79.40133 43.67541)
# 388714 -79.580404   POINT (-79.5804 43.73631)
# 388715 -79.580404   POINT (-79.5804 43.73631)
# 388716 -79.282891   POINT (-79.28289 43.7179)
# 388717 -79.282891   POINT (-79.28289 43.7179)
#
# [388718 rows x 20 columns]

# %%
df[df['sector']=='Men']
# Out:
#                  date_time                             shelter_name  \
# 1      2017-01-01 04:00:00          Christie Ossington Men's Hostel
# 2      2017-01-01 04:00:00          Christie Ossington Men's Hostel
# 6      2017-01-01 04:00:00                          Downsview Dells
# 16     2017-01-01 04:00:00                      Fort York Residence
# 17     2017-01-01 04:00:00                      Fort York Residence
# ...                    ...                                      ...
# 388696 2025-10-28 04:00:00                   Etobicoke Hotel Site 1
# 388697 2025-10-28 04:00:00                  SA New Hope Leslieville
# 388698 2025-10-28 04:00:00            SA Islington Seniors' Shelter
# 388700 2025-10-28 04:00:00  The Scott Mission - Kensington location
# 388701 2025-10-28 04:00:00                            Scott Mission
#
#                                              program_name sector  \
# 1              Christie Ossington Extreme Weather Program    Men
# 2                         Christie Ossington Men's Hostel    Men
# 6                          Downsview Dells Bedded Program    Men
# 16                      Fort York Extreme Weather Program    Men
# 17                     Fort York Residence Bedded Program    Men
# ...                                                   ...    ...
# 388696        Salvation Army - New Hope - Hotel 400 - Men    Men
# 388697           Salvation Army - New Hope - Men's Hostel    Men
# 388698  Salvation Army - Islington Seniors' Shelter Me...    Men
# 388700   Scott Mission - Men's Ministry Overnight Program    Men
# 388701                            Scott Mission - Respite    Men
#
#                shelter_address shelter_city shelter_postal_code data_schema  \
# 1         973 Lansdowne Avenue      Toronto             M6H 3Z5    pre_2021
# 2         973 Lansdowne Avenue      Toronto             M6H 3Z5    pre_2021
# 6       1651 Sheppard Ave West      Toronto             M3M 2X4    pre_2021
# 16              38 Bathrust St      Toronto             M5V 3W3    pre_2021
# 17              38 Bathrust St      Toronto             M5V 3W3    pre_2021
# ...                        ...          ...                 ...         ...
# 388696          66 Norfinch Dr   North York             M3N 1X1   post_2021
# 388697           29A Leslie St      Toronto             M4M 3C3   post_2021
# 388698      2671 Islington Ave      Toronto             M9V 2X6   post_2021
# 388700        346 Spadina Ave.      Toronto             M5T 1J5   post_2021
# 388701         502 Spadina Ave      Toronto             M5S 2H1   post_2021
#
#         year        capacity_type  capacity_combined  occupancy_combined  \
# 1       2017   Bed Based Capacity               17.0                13.0
# 2       2017   Bed Based Capacity               63.0                63.0
# 6       2017   Bed Based Capacity               28.0                23.0
# 16      2017   Bed Based Capacity               19.0                 0.0
# 17      2017   Bed Based Capacity               74.0                74.0
# ...      ...                  ...                ...                 ...
# 388696  2025  Room Based Capacity               52.0                52.0
# 388697  2025   Bed Based Capacity               52.0                52.0
# 388698  2025   Bed Based Capacity               46.0                46.0
# 388700  2025   Bed Based Capacity               71.0                71.0
# 388701  2025   Bed Based Capacity               50.0                50.0
#
#         occupancy_rate_combined  month  day  weekday  is_weekend        lat  \
# 1                      0.764706      1    1   Sunday        True  43.666104
# 2                      1.000000      1    1   Sunday        True  43.666104
# 6                      0.821429      1    1   Sunday        True  43.740637
# 16                     0.000000      1    1   Sunday        True  43.641175
# 17                     1.000000      1    1   Sunday        True  43.641175
# ...                         ...    ...  ...      ...         ...        ...
# 388696                 1.000000     10   28  Tuesday       False  43.757402
# 388697                 1.000000     10   28  Tuesday       False  43.661904
# 388698                 1.000000     10   28  Tuesday       False  43.739300
# 388700                 1.000000     10   28  Tuesday       False  43.654182
# 388701                 1.000000     10   28  Tuesday       False  43.658651
#
#               lon
# 1      -79.446019
# 2      -79.446019
# 6      -79.494160
# 16     -79.402516
# 17     -79.402516
# ...           ...
# 388696 -79.529568
# 388697 -79.329352
# 388698 -79.565871
# 388700 -79.398936
# 388701 -79.400797
#
# [108796 rows x 19 columns]

# %%
import matplotlib.pyplot as plt

# %%
bed_df = gdf[gdf['capacity_type'].str.contains('Bed', case=False, na=False)]
room_df = gdf[gdf['capacity_type'].str.contains('Room', case=False, na=False)]

fig, axes = plt.subplots(1, 2, figsize=(12,5), sharey=True)

bed_sector_counts.plot(kind='bar', ax=axes[0])
axes[0].set_title('Bed-Based Capacity by Sector')
axes[0].set_xlabel('Sector')
axes[0].set_ylabel('Number of Records')
axes[0].tick_params(axis='x', rotation=45)

room_sector_counts.plot(kind='bar', ax=axes[1])
axes[1].set_title('Room-Based Capacity by Sector')
axes[1].set_xlabel('Sector')
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 6
#       2 room_df = gdf[gdf['capacity_type'].str.contains('Room', case=False, na=False)]
#       4 fig, axes = plt.subplots(1, 2, figsize=(12,5), sharey=True)
# ----> 6 bed_sector_counts.plot(kind='bar', ax=axes[0])
#       7 axes[0].set_title('Bed-Based Capacity by Sector')
#       8 axes[0].set_xlabel('Sector')
#
# NameError: name 'bed_sector_counts' is not defined

# %%
bed_df = gdf[gdf['capacity_type'].str.contains('Bed', case=False, na=False)]
room_df = gdf[gdf['capacity_type'].str.contains('Room', case=False, na=False)]

bed_counts = (bed_df.groupby(['sector', bed_df['program_name'].str.contains('refugee', case=False, na=False)]).size().unstack(fill_value=0).rename(columns={True: 'Refugee', False: 'Non-Refugee'})[["Refugee", "Non-Refugee"]])

room_counts = (room_df.groupby(['sector', room_df['program_name'].str.contains('refugee', case=False, na=False)]).size().unstack(fill_value=0).rename(columns={True: 'Refugee', False: 'Non-Refugee'})[["Refugee", "Non-Refugee"]])

bed_counts = bed_counts.loc[bed_counts.sum(axis=1).sort_values(ascending=False).index]
room_counts = room_counts.loc[room_counts.sum(axis=1).sort_values(ascending=False).index]
fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

bed_counts.plot(kind="bar",stacked=True,ax=axes[0])
axes[0].set_title("Bed-Based Capacity by Sector")
axes[0].set_xlabel("Sector")
axes[0].set_ylabel("Number of Records")
axes[0].tick_params(axis="x", rotation=45, labelsize=9)

room_counts.plot(kind="bar",stacked=True,ax=axes[1])
axes[1].set_title("Room-Based Capacity by Sector")
axes[1].set_xlabel("Sector")
axes[1].tick_params(axis="x", rotation=45, labelsize=9)

plt.tight_layout()
plt.show()

# %%
bed_df = gdf[gdf['capacity_type'].str.contains('Bed', case=False, na=False)]
room_df = gdf[gdf['capacity_type'].str.contains('Room', case=False, na=False)]

def summarize_refugee_counts(df, label):
    summary = df.groupby(['sector', df['program_name'].str.contains('refugee', case=False, na=False)]).size().unstack(fill_value=0).rename(columns={True: 'Refugee_Records', False: 'NonRefugee_Records'}).assign(Capacity_Type=label).reset_index()
    loc_refugee = df[df['program_name'].str.contains('refugee', case=False, na=False)].groupby('sector')['shelter_name'].nunique().rename('Refugee_Locations')
    loc_nonref = df[~df['program_name'].str.contains('refugee', case=False, na=False)].groupby('sector')['shelter_name'].nunique().rename('NonRefugee_Locations')
    loc_total = df.groupby('sector')['shelter_name'].nunique().rename('Total_Locations')
    loc_summary = pd.concat([loc_refugee, loc_nonref, loc_total], axis=1).fillna(0).reset_index()
    summary = summary.merge(loc_summary, on='sector', how='left')
    summary['Total_Records'] = summary['Refugee_Records'] + summary['NonRefugee_Records']
    return summary

bed_summary = summarize_refugee_counts(bed_df, "Bed-Based")
room_summary = summarize_refugee_counts(room_df, "Room-Based")
capacity_summary = pd.concat([bed_summary, room_summary], ignore_index=True)
capacity_summary = capacity_summary.sort_values(by='Total_Records', ascending=False).reset_index(drop=True)
capacity_summary = capacity_summary[['sector', 'Capacity_Type', 'Refugee_Records', 'NonRefugee_Records', 'Total_Records', 'Refugee_Locations', 'NonRefugee_Locations', 'Total_Locations']]

display(capacity_summary.style.set_caption("Shelter Records and Unique Locations by Sector, Capacity Type, and Refugee Status").background_gradient(subset=["Refugee_Records", "NonRefugee_Records", "Total_Records"], cmap="YlGnBu").background_gradient(subset=["Refugee_Locations", "NonRefugee_Locations", "Total_Locations"], cmap="PuBuGn").format(precision=0))
# Out:
# <style type="text/css">
# #T_74e21_row0_col2 {
#   background-color: #a5dcb7;
#   color: #000000;
# }
# #T_74e21_row0_col3, #T_74e21_row0_col4, #T_74e21_row5_col2 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_74e21_row0_col5, #T_74e21_row1_col5, #T_74e21_row5_col6 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_74e21_row0_col6, #T_74e21_row0_col7, #T_74e21_row3_col7, #T_74e21_row5_col5 {
#   background-color: #014636;
#   color: #f1f1f1;
# }
# #T_74e21_row1_col2, #T_74e21_row5_col4, #T_74e21_row6_col4 {
#   background-color: #d4eeb3;
#   color: #000000;
# }
# #T_74e21_row1_col3, #T_74e21_row1_col4 {
#   background-color: #1e85ba;
#   color: #f1f1f1;
# }
# #T_74e21_row1_col6 {
#   background-color: #04828c;
#   color: #f1f1f1;
# }
# #T_74e21_row1_col7 {
#   background-color: #027e83;
#   color: #f1f1f1;
# }
# #T_74e21_row2_col2 {
#   background-color: #dff2b2;
#   color: #000000;
# }
# #T_74e21_row2_col3, #T_74e21_row2_col4 {
#   background-color: #2ca1c2;
#   color: #f1f1f1;
# }
# #T_74e21_row2_col5 {
#   background-color: #258bae;
#   color: #f1f1f1;
# }
# #T_74e21_row2_col6 {
#   background-color: #58a2cb;
#   color: #f1f1f1;
# }
# #T_74e21_row2_col7 {
#   background-color: #3a92c1;
#   color: #f1f1f1;
# }
# #T_74e21_row3_col2 {
#   background-color: #c6e9b4;
#   color: #000000;
# }
# #T_74e21_row3_col3 {
#   background-color: #83cebb;
#   color: #000000;
# }
# #T_74e21_row3_col4 {
#   background-color: #7ecdbb;
#   color: #000000;
# }
# #T_74e21_row3_col5 {
#   background-color: #66a9cf;
#   color: #f1f1f1;
# }
# #T_74e21_row3_col6 {
#   background-color: #014d3d;
#   color: #f1f1f1;
# }
# #T_74e21_row4_col2 {
#   background-color: #2ea3c2;
#   color: #f1f1f1;
# }
# #T_74e21_row4_col3 {
#   background-color: #dbf1b2;
#   color: #000000;
# }
# #T_74e21_row4_col4 {
#   background-color: #d0edb3;
#   color: #000000;
# }
# #T_74e21_row4_col5, #T_74e21_row7_col5 {
#   background-color: #017369;
#   color: #f1f1f1;
# }
# #T_74e21_row4_col6 {
#   background-color: #93b7d7;
#   color: #000000;
# }
# #T_74e21_row4_col7 {
#   background-color: #6eabd0;
#   color: #f1f1f1;
# }
# #T_74e21_row5_col3 {
#   background-color: #e7f6b1;
#   color: #000000;
# }
# #T_74e21_row5_col7 {
#   background-color: #7aafd3;
#   color: #f1f1f1;
# }
# #T_74e21_row6_col2 {
#   background-color: #e6f5b2;
#   color: #000000;
# }
# #T_74e21_row6_col3, #T_74e21_row7_col4 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_74e21_row6_col5 {
#   background-color: #e3dded;
#   color: #000000;
# }
# #T_74e21_row6_col6, #T_74e21_row6_col7 {
#   background-color: #d4d4e7;
#   color: #000000;
# }
# #T_74e21_row7_col2 {
#   background-color: #1c2d81;
#   color: #f1f1f1;
# }
# #T_74e21_row7_col3 {
#   background-color: #e8f6b1;
#   color: #000000;
# }
# #T_74e21_row7_col6 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_74e21_row7_col7 {
#   background-color: #f4eaf4;
#   color: #000000;
# }
# #T_74e21_row8_col2, #T_74e21_row9_col2, #T_74e21_row10_col2, #T_74e21_row10_col3, #T_74e21_row10_col4 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_74e21_row8_col3, #T_74e21_row8_col4 {
#   background-color: #f9fdcc;
#   color: #000000;
# }
# #T_74e21_row8_col5, #T_74e21_row8_col6, #T_74e21_row8_col7, #T_74e21_row9_col5, #T_74e21_row10_col5, #T_74e21_row10_col6, #T_74e21_row10_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_74e21_row9_col3, #T_74e21_row9_col4 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_74e21_row9_col6, #T_74e21_row9_col7 {
#   background-color: #f7eef7;
#   color: #000000;
# }
# </style>
# <table id="T_74e21">
#   <caption>Shelter Records and Unique Locations by Sector, Capacity Type, and Refugee Status</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74e21_level0_col0" class="col_heading level0 col0" >sector</th>
#       <th id="T_74e21_level0_col1" class="col_heading level0 col1" >Capacity_Type</th>
#       <th id="T_74e21_level0_col2" class="col_heading level0 col2" >Refugee_Records</th>
#       <th id="T_74e21_level0_col3" class="col_heading level0 col3" >NonRefugee_Records</th>
#       <th id="T_74e21_level0_col4" class="col_heading level0 col4" >Total_Records</th>
#       <th id="T_74e21_level0_col5" class="col_heading level0 col5" >Refugee_Locations</th>
#       <th id="T_74e21_level0_col6" class="col_heading level0 col6" >NonRefugee_Locations</th>
#       <th id="T_74e21_level0_col7" class="col_heading level0 col7" >Total_Locations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74e21_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_74e21_row0_col0" class="data row0 col0" >Men</td>
#       <td id="T_74e21_row0_col1" class="data row0 col1" >Bed-Based</td>
#       <td id="T_74e21_row0_col2" class="data row0 col2" >2013</td>
#       <td id="T_74e21_row0_col3" class="data row0 col3" >97584</td>
#       <td id="T_74e21_row0_col4" class="data row0 col4" >99597</td>
#       <td id="T_74e21_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_74e21_row0_col6" class="data row0 col6" >47</td>
#       <td id="T_74e21_row0_col7" class="data row0 col7" >47</td>
#     </tr>
#     <tr>
#       <th id="T_74e21_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_74e21_row1_col0" class="data row1 col0" >Women</td>
#       <td id="T_74e21_row1_col1" class="data row1 col1" >Bed-Based</td>
#       <td id="T_74e21_row1_col2" class="data row1 col2" >1348</td>
#       <td id="T_74e21_row1_col3" class="data row1 col3" >65662</td>
#       <td id="T_74e21_row1_col4" class="data row1 col4" >67010</td>
#       <td id="T_74e21_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_74e21_row1_col6" class="data row1 col6" >37</td>
#       <td id="T_74e21_row1_col7" class="data row1 col7" >38</td>
#     </tr>
#     <tr>
#       <th id="T_74e21_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_74e21_row2_col0" class="data row2 col0" >Youth</td>
#       <td id="T_74e21_row2_col1" class="data row2 col1" >Bed-Based</td>
#       <td id="T_74e21_row2_col2" class="data row2 col2" >1137</td>
#       <td id="T_74e21_row2_col3" class="data row2 col3" >58238</td>
#       <td id="T_74e21_row2_col4" class="data row2 col4" >59375</td>
#       <td id="T_74e21_row2_col5" class="data row2 col5" >4</td>
#       <td id="T_74e21_row2_col6" class="data row2 col6" >29</td>
#       <td id="T_74e21_row2_col7" class="data row2 col7" >32</td>
#     </tr>
#     <tr>
#       <th id="T_74e21_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_74e21_row3_col0" class="data row3 col0" >Mixed Adult</td>
#       <td id="T_74e21_row3_col1" class="data row3 col1" >Bed-Based</td>
#       <td id="T_74e21_row3_col2" class="data row3 col2" >1644</td>
#       <td id="T_74e21_row3_col3" class="data row3 col3" >39289</td>
#       <td id="T_74e21_row3_col4" class="data row3 col4" >40933</td>
#       <td id="T_74e21_row3_col5" class="data row3 col5" >3</td>
#       <td id="T_74e21_row3_col6" class="data row3 col6" >46</td>
#       <td id="T_74e21_row3_col7" class="data row3 col7" >47</td>
#     </tr>
#     <tr>
#       <th id="T_74e21_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_74e21_row4_col0" class="data row4 col0" >Mixed Adult</td>
#       <td id="T_74e21_row4_col1" class="data row4 col1" >Room-Based</td>
#       <td id="T_74e21_row4_col2" class="data row4 col2" >3657</td>
#       <td id="T_74e21_row4_col3" class="data row4 col3" >22377</td>
#       <td id="T_74e21_row4_col4" class="data row4 col4" >26034</td>
#       <td id="T_74e21_row4_col5" class="data row4 col5" >5</td>
#       <td id="T_74e21_row4_col6" class="data row4 col6" >24</td>
#       <td id="T_74e21_row4_col7" class="data row4 col7" >27</td>
#     </tr>
#     <tr>
#       <th id="T_74e21_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_74e21_row5_col0" class="data row5 col0" >Families</td>
#       <td id="T_74e21_row5_col1" class="data row5 col1" >Room-Based</td>
#       <td id="T_74e21_row5_col2" class="data row5 col2" >6493</td>
#       <td id="T_74e21_row5_col3" class="data row5 col3" >18631</td>
#       <td id="T_74e21_row5_col4" class="data row5 col4" >25124</td>
#       <td id="T_74e21_row5_col5" class="data row5 col5" >6</td>
#       <td id="T_74e21_row5_col6" class="data row5 col6" >21</td>
#       <td id="T_74e21_row5_col7" class

# %%
demand_est = df.groupby('shelter_name')['occupancy_combined'].max()
print("Approx total demand across all shelters:", demand_est)
# Out:
# Approx total demand across all shelters: shelter_name
# 18 Fourteen Street                        33.6
# 213 Carlton Street                        18.0
# 354 George Street                         60.0
# 45 The Esplanade                         283.2
# 885 Scarborough Golf Club Road            79.2
#                                          ...
# Youth Agencies Downtown Hotel Program     61.2
# Youth Without Shelter                     39.6
# Youth Without Shelter                     39.6
# YouthLink                                 49.2
# YouthLink Shelter                         49.2
# Name: occupancy_combined, Length: 213, dtype: float64

# %%
capacity = pd.DataFrame(df.groupby('shelter_name')['capacity_combined'].mean())
max_occupancy = pd.DataFrame(df.groupby('shelter_name')['occupancy_combined'].max())
demand_df = pd.merge(capacity, max_occupancy, left_index=True, right_index=True)

# %%
alpha = 1.5
demand_df['estimate'] = np.where(demand_df['occupancy_combined'] >= demand_df['capacity_combined'],demand_df['capacity_combined'] * alpha,demand_df['occupancy_combined'])
demand_df
# Out:
#                                        capacity_combined  occupancy_combined  \
# shelter_name
# 18 Fourteen Street                             23.076923                28.0
# 213 Carlton Street                             12.089385                15.0
# 354 George Street                              43.736000                50.0
# 45 The Esplanade                              199.637346               236.0
# 885 Scarborough Golf Club Road                 42.425926                66.0
# ...                                                  ...                 ...
# Youth Agencies Downtown Hotel Program          26.527594                51.0
# Youth Without Shelter                          25.406913                33.0
# Youth Without Shelter                          21.877401                33.0
# YouthLink                                      22.816788                41.0
# YouthLink Shelter                              23.429160                41.0
#
#                                          estimate
# shelter_name
# 18 Fourteen Street                      34.615385
# 213 Carlton Street                      18.134078
# 354 George Street                       65.604000
# 45 The Esplanade                       299.456019
# 885 Scarborough Golf Club Road          63.638889
# ...                                           ...
# Youth Agencies Downtown Hotel Program   39.791391
# Youth Without Shelter                   38.110370
# Youth Without Shelter                   32.816102
# YouthLink                               34.225181
# YouthLink Shelter                       35.143740
#
# [213 rows x 3 columns]

# %%
capacity = pd.DataFrame(df.groupby(['date_time', 'shelter_name'])['capacity_combined'].max())
max_occupancy = pd.DataFrame(df.groupby(['date_time', 'shelter_name'])['occupancy_combined'].max())
demand_df = pd.merge(capacity, max_occupancy, left_index=True, right_index=True)

# %%
demand_df['estimate'] = np.where(demand_df['occupancy_combined'] >= demand_df['capacity_combined'], demand_df['capacity_combined'] * 1.05,demand_df['occupancy_combined'])
demand_df = demand_df.reset_index()
demand_df

#
# Out:
#                  date_time                     shelter_name  \
# 0      2017-01-01 04:00:00               Birkdale Residence
# 1      2017-01-01 04:00:00           COSTI Reception Centre
# 2      2017-01-01 04:00:00  Christie Ossington Men's Hostel
# 3      2017-01-01 04:00:00  Christie Refugee Welcome Centre
# 4      2017-01-01 04:00:00                Cornerstone Place
# ...                    ...                              ...
# 252719 2025-11-05 04:00:00               YMCA Sprott House
# 252720 2025-11-05 04:00:00          YWCA 1st Stop Woodlawn
# 252721 2025-11-05 04:00:00           YWCA Davenport Shelter
# 252722 2025-11-05 04:00:00           Youth Without Shelter
# 252723 2025-11-05 04:00:00                       YouthLink
#
#         capacity_combined  occupancy_combined  estimate
# 0                   160.0               168.0    168.00
# 1                    16.0                16.0     16.80
# 2                    63.0                63.0     66.15
# 3                    70.0                66.0     66.00
# 4                    50.0                50.0     52.50
# ...                   ...                 ...       ...
# 252719               25.0                24.0     24.00
# 252720               31.0                31.0     32.55
# 252721               38.0                38.0     39.90
# 252722               33.0                31.0     31.00
# 252723               41.0                37.0     37.00
#
# [252724 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
# Filter once for readability
for i in range(len(demand_df['shelter_name'].unique())):
    shelter = demand_df['shelter_name'][i]
    birkdale = demand_df[demand_df['shelter_name'] == shelter].copy()

    # Convert date_time to numeric for regression
    birkdale = birkdale.sort_values('date_time')
    x = (birkdale['date_time'] - birkdale['date_time'].min()).dt.total_seconds() / 3600  # convert to hours
    y = birkdale['estimate']

    # Fit a linear regression line (y = m*x + b)
    m, b = np.polyfit(x, y, 1)
    trend = m * x + b

    # Plot
    plt.figure(figsize=(10, 5))
    plt.plot(birkdale['date_time'], y, marker='o', linestyle='-', linewidth=1.5, markersize=4, label='Estimated Demand')
    plt.plot(birkdale['date_time'], trend, color='red', linestyle='--', linewidth=2, label=f'Trend Line (slope={m:.2f})')

    # Style & labels
    plt.title(f'Estimated Demand Over Time — {shelter}', fontsize=14, pad=12)
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Estimated Occupancy', fontsize=12)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %%
from sklearn.linear_model import LinearRegression

df_filtered = df[(df['year'] >= 2021) & (df['year'] <= 2026)]

monthly_occupancy = (df_filtered.groupby(['year', 'month'])['occupancy_combined'].sum().reset_index().sort_values(['year', 'month']))
monthly_occupancy['date'] = pd.to_datetime(monthly_occupancy['year'].astype(str) + '-' + monthly_occupancy['month'].astype(str) + '-01')

X = np.arange(len(monthly_occupancy)).reshape(-1, 1)
y = monthly_occupancy['occupancy_combined'].values
model = LinearRegression().fit(X, y)
y_pred = model.predict(X)

plt.plot(monthly_occupancy['date'], monthly_occupancy['occupancy_combined'], 'o-', label='Monthly Total Occupancy')
plt.plot(monthly_occupancy['date'], y_pred, '--', linewidth=2, label='Trend Line (Linear Fit)', color='orange')
plt.title('Monthly Shelter Occupancy in Toronto (2021–2026)')
plt.xlabel('Date')
plt.ylabel('Total People in Shelters')
plt.legend()
plt.show()

# %%
shelter_summary = (
    gdf.groupby("shelter_name")
       .agg(
           capacity=("capacity_combined", "mean"),
           avg_occupancy=("occupancy_combined", "mean"),
           lat=("lat", "mean"),
           lon=("lon", "mean")
       )
       .dropna(subset=["capacity"])
)
shelter_summary["utilization"] = shelter_summary["avg_occupancy"] / shelter_summary["capacity"]
shelter_summary.head()
# Out:
#                                   capacity  avg_occupancy        lat  \
# shelter_name
# 18 Fourteen Street               23.076923      20.923077  43.653226
# 213 Carlton Street               12.070175      10.119883  43.663788
# 354 George Street                43.736000      43.272000 -33.867236
# 45 The Esplanade                199.637346     199.516975  43.647076
# 885 Scarborough Golf Club Road   42.425926      37.033333  43.772810
#
#                                        lon  utilization
# shelter_name
# 18 Fourteen Street              -79.383184     0.906667
# 213 Carlton Street              -79.369542     0.838421
# 354 George Street               151.207421     0.989391
# 45 The Esplanade                -79.374966     0.999397
# 885 Scarborough Golf Club Road  -79.219236     0.872894

# %%
df['utilization_rate'].describe()
# Out:
# count    384982.000000
# mean          0.945496
# std           0.188039
# min           0.000000
# 25%           0.960000
# 50%           1.000000
# 75%           1.000000
# max           4.350000
# Name: utilization_rate, dtype: float64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df['year_month'] = df['date_time'].dt.to_period('M')

trend_df = (df.groupby(['shelter_name', 'year_month'])['occupancy_combined'].mean().reset_index())
trend_df['month_index'] = trend_df['year_month'].apply(lambda x: x.to_timestamp()).map(pd.Timestamp.toordinal)

slopes = []
for name, sub in trend_df.groupby('shelter_name'):
    if len(sub) > 5:
        slope, intercept = np.polyfit(sub['month_index'], sub['occupancy_combined'], 1)
        slopes.append({'shelter_name': name, 'slope': slope, 'start': sub['occupancy_combined'].iloc[0], 'end': sub['occupancy_combined'].iloc[-1]})
        
trend_summary = pd.DataFrame(slopes)
trend_summary['change'] = trend_summary['end'] - trend_summary['start']

declining_shelters = trend_summary.sort_values('slope').head(10)

plt.figure(figsize=(10,6))
plt.barh(declining_shelters['shelter_name'], declining_shelters['slope'], color='tomato')
plt.title('Top 10 Shelters with Declining Occupancy Trends')
plt.xlabel('Occupancy Trend (Slope)')
plt.ylabel('Shelter Name')
plt.show()

# %%
top_decliners = declining_shelters['shelter_name'].head(5)
plt.figure(figsize=(10,6))
for s in top_decliners:
    subset = trend_df[trend_df['shelter_name'] == s]
    plt.plot(subset['year_month'].dt.to_timestamp(), subset['occupancy_combined'], label=s)

plt.legend()
plt.title("Occupancy Trends for Declining Shelters")
plt.xlabel("Date")
plt.ylabel("Average Occupancy")
plt.tight_layout()
plt.show()

# %%
top_decliners = ["Downtown Hotel Program - York",
                 "Dixon Hall Bond Place Hotel Program",
                 "CRC Hotel Program Eglinton",
                 "CRC Hotel Program Dixon",
                 "COSTI Reception Centre"]

plt.figure(figsize=(12,6))
for shelter in top_decliners:
    subset = df[df['shelter_name'] == shelter]
    monthly = (subset.groupby(subset['date_time'].dt.to_period('M'))[['occupancy_combined', 'capacity_combined']].mean().reset_index())
    monthly['date'] = monthly['date_time'].dt.to_timestamp()
    plt.plot(monthly['date'], monthly['occupancy_combined'], label=f"{shelter} - Occupancy")
    plt.plot(monthly['date'], monthly['capacity_combined'], label=f"{shelter} - Capacity")
plt.title("Occupancy vs Capacity Trends for Declining Shelters")
plt.xlabel("Date")
plt.ylabel("Average Beds / Rooms")
plt.legend()
plt.show()

# %% [markdown]
# reason for decline in occupancy rates is cuts in budget resulting in less available capacity

# %%
df
# Out:
#                  date_time                     shelter_name  \
# 0      2017-01-01 04:00:00           COSTI Reception Centre
# 1      2017-01-01 04:00:00  Christie Ossington Men's Hostel
# 2      2017-01-01 04:00:00  Christie Ossington Men's Hostel
# 3      2017-01-01 04:00:00  Christie Refugee Welcome Centre
# 4      2017-01-01 04:00:00               Birkdale Residence
# ...                    ...                              ...
# 388713 2025-10-28 04:00:00           YWCA Davenport Shelter
# 388714 2025-10-28 04:00:00           Youth Without Shelter
# 388715 2025-10-28 04:00:00           Youth Without Shelter
# 388716 2025-10-28 04:00:00                       YouthLink
# 388717 2025-10-28 04:00:00                       YouthLink
#
#                                              program_name    sector  \
# 0                        COSTI Reception Ctr CITY Program     Co-ed
# 1              Christie Ossington Extreme Weather Program       Men
# 2                         Christie Ossington Men's Hostel       Men
# 3       Christie Refugee Welcome Ctr - Settlement and ...  Families
# 4                     Birkdale Residence - Bedded Program  Families
# ...                                                   ...       ...
# 388713                             YWCA Davenport - Youth     Youth
# 388714    Youth without Shelter Emergency Shelter Program     Youth
# 388715       Youth without Shelter Stay In School Program     Youth
# 388716                        YouthLink Emergency Program     Youth
# 388717                     YouthLink Transitional Program     Youth
#
#               shelter_address shelter_city shelter_postal_code data_schema  \
# 0       100 Lippincott Street      Toronto             M5S 2P1    pre_2021
# 1        973 Lansdowne Avenue      Toronto             M6H 3Z5    pre_2021
# 2        973 Lansdowne Avenue      Toronto             M6H 3Z5    pre_2021
# 3          43 Christie Street      Toronto             M6G 3B1    pre_2021
# 4         1229 Ellesmere Road      Toronto             M1P 4V8    pre_2021
# ...                       ...          ...                 ...         ...
# 388713     348 Davenport Road      Toronto             M5R 1K6   post_2021
# 388714        6 Warrendale Ct    Etobicoke             M9V 1P9   post_2021
# 388715        6 Warrendale Ct    Etobicoke             M9V 1P9   post_2021
# 388716         747 Warden Ave  Scarborough             M1L 4A1   post_2021
# 388717         747 Warden Ave  Scarborough             M1L 4A1   post_2021
#
#         year       capacity_type  capacity_combined  occupancy_combined  \
# 0       2017  Bed Based Capacity               16.0                16.0
# 1       2017  Bed Based Capacity               17.0                13.0
# 2       2017  Bed Based Capacity               63.0                63.0
# 3       2017  Bed Based Capacity               70.0                66.0
# 4       2017  Bed Based Capacity              160.0               168.0
# ...      ...                 ...                ...                 ...
# 388713  2025  Bed Based Capacity               26.0                25.0
# 388714  2025  Bed Based Capacity               33.0                33.0
# 388715  2025  Bed Based Capacity               20.0                20.0
# 388716  2025  Bed Based Capacity               10.0                10.0
# 388717  2025  Bed Based Capacity               41.0                37.0
#
#         occupancy_rate_combined  month  day  weekday  is_weekend        lat  \
# 0                      1.000000      1    1   Sunday        True  43.657562
# 1                      0.764706      1    1   Sunday        True  43.666104
# 2                      1.000000      1    1   Sunday        True  43.666104
# 3                      0.942857      1    1   Sunday        True  43.665203
# 4                      1.050000      1    1   Sunday        True  43.768282
# ...                         ...    ...  ...      ...         ...        ...
# 388713                 0.961538     10   28  Tuesday       False  43.675412
# 388714                 1.000000     10   28  Tuesday       False  43.736310
# 388715                 1.000000     10   28  Tuesday       False  43.736310
# 388716                 1.000000     10   28  Tuesday       False  43.717903
# 388717                 0.902439     10   28  Tuesday       False  43.717903
#
#               lon  utilization_rate
# 0      -79.407393          1.000000
# 1      -79.446019          0.764706
# 2      -79.446019          1.000000
# 3      -79.418857          0.942857
# 4      -79.267447          1.050000
# ...           ...               ...
# 388713 -79.401333          0.961538
# 388714 -79.580404          1.000000
# 388715 -79.580404          1.000000
# 388716 -79.282891          1.000000
# 388717 -79.282891          0.902439
#
# [388718 rows x 20 columns]

# %%
import geopandas as gpd; import pandas as pd; import matplotlib.pyplot as plt

shapefile_path=r"C:\Users\roanp\Downloads\Neighbourhoods - 4326.geojson"

neighbourhoods=gpd.read_file(shapefile_path); neighbourhoods.columns=neighbourhoods.columns.str.lower()
neighbourhoods=neighbourhoods[['area_name','geometry']]; neighbourhoods['type']='neighbourhood'
gdf=gdf.to_crs(neighbourhoods.crs)
shelter_locations=gdf[['shelter_name','geometry']].copy(); shelter_locations.columns=['area_name','geometry']; shelter_locations['type']='shelter'

minx,miny,maxx,maxy=-79.64,43.58,-79.12,43.85
shelter_locations=shelter_locations.cx[minx:maxx,miny:maxy]

gdf_all=gpd.GeoDataFrame(pd.concat([shelter_locations,neighbourhoods],ignore_index=True),geometry='geometry',crs=neighbourhoods.crs)
fig,ax=plt.subplots(figsize=(8,8))
gdf_all[gdf_all['type']=='neighbourhood'].plot(ax=ax,color='lightgrey',alpha=0.5,edgecolor='white',linewidth=0.3)

gdf_all[gdf_all['type']=='neighbourhood'].boundary.plot(ax=ax,color='grey',linewidth=0.4,alpha=0.7)
gdf_all[gdf_all['type']=='shelter'].plot(ax=ax,color='red',markersize=25,alpha=0.9,zorder=3)
ax.set_title("Toronto Neighbourhoods and Shelter Locations",fontsize=12,weight='bold',pad=10); ax.set_axis_off(); ax.margins(0); plt.tight_layout(pad=1.5)

plt.annotate("Data Source: City of Toronto Open Data (2017–2025)",xy=(0.5,-0.08),xycoords='axes fraction',ha='center',fontsize=8,color='dimgray'); plt.show()

# %%
minx, miny, maxx, maxy = -79.64, 43.58, -79.12, 43.85
gdf = gdf.cx[minx:maxx, miny:maxy]

# %%
shelter_summary = gdf.groupby(['shelter_name', 'lat', 'lon'], as_index=False).agg({
    'occupancy_combined': 'mean',
    'capacity_combined': 'mean',
    'occupancy_rate_combined': 'mean'
})
shelter_summary_gdf = gpd.GeoDataFrame(
    shelter_summary,
    geometry=gpd.points_from_xy(shelter_summary['lon'], shelter_summary['lat']),
    crs="EPSG:4326"
)

# %%
import matplotlib.pyplot as plt; import geopandas as gpd

shelter_summary_gdf=shelter_summary_gdf.to_crs(neighbourhoods.crs); shelters_with_neigh=gpd.sjoin(shelter_summary_gdf,neighbourhoods,how="left",predicate="within")

neighbourhood_activity=(shelters_with_neigh.groupby('area_name',as_index=False).agg({'occupancy_combined':'sum','capacity_combined':'sum','occupancy_rate_combined':'mean'}))
neighbourhoods_heatmap=neighbourhoods.merge(neighbourhood_activity,on='area_name',how='left')
fig,ax=plt.subplots(figsize=(8,8))

neighbourhoods_heatmap.plot(column='occupancy_combined',cmap='Reds',linewidth=0.3,edgecolor='white',legend=True,legend_kwds={'label':"Total Shelter Occupancy",'orientation':'vertical','shrink':0.6,'pad':0.02},ax=ax)

neighbourhoods.boundary.plot(ax=ax,color='grey',linewidth=0.4,alpha=0.7)
ax.set_title("Toronto Homelessness Hotspots by Neighbourhood",fontsize=12,weight='bold',pad=10); ax.set_axis_off(); ax.margins(0); plt.tight_layout(pad=1.5)

plt.annotate("Data Source: City of Toronto Open Data (2017–2025)",xy=(0.5,-0.08),xycoords='axes fraction',ha='center',fontsize=8,color='dimgray'); plt.show()

# %%
gdf = gpd.sjoin(gdf, neighbourhoods[['area_name', 'geometry']], how='left', predicate='within')

# %%
gdf['date'] = pd.to_datetime(gdf['date_time']).dt.date

daily = gdf.groupby(['area_name', 'date'], as_index=False).agg({'occupancy_combined': 'sum'})
daily['arrival'] = daily.groupby('area_name')['occupancy_combined'].diff().clip(lower=0)

arrival_rate = daily.groupby('area_name', as_index=False)['arrival'].mean()
arrival_rate.rename(columns={'arrival': 'lambda_arrival_rate'}, inplace=True)

neighbourhoods_rate = neighbourhoods.merge(arrival_rate, on='area_name', how='left')
neighbourhoods_rate.sort_values(by='lambda_arrival_rate', ascending=False)
# Out:
#                 area_name                                           geometry  \
# 11            Yonge-Doris  MULTIPOLYGON (((-79.40961 43.7618, -79.41094 4...
# 79             University  MULTIPOLYGON (((-79.39963 43.65798, -79.39976 ...
# 82              Moss Park  MULTIPOLYGON (((-79.36462 43.65601, -79.36446 ...
# 124                Rustic  MULTIPOLYGON (((-79.50369 43.70292, -79.50384 ...
# 6     Bendale-Glen Andrew  MULTIPOLYGON (((-79.26392 43.75175, -79.26505 ...
# ..                    ...                                                ...
# 149      Elms-Old Rexdale  MULTIPOLYGON (((-79.54677 43.73156, -79.54632 ...
# 150       Rexdale-Kipling  MULTIPOLYGON (((-79.56419 43.71229, -79.5667 4...
# 155  Pelmo Park-Humberlea  MULTIPOLYGON (((-79.53225 43.73505, -79.52938 ...
# 156            Humbermede  MULTIPOLYGON (((-79.52813 43.74425, -79.52721 ...
# 157         Humber Summit  MULTIPOLYGON (((-79.53396 43.76886, -79.53227 ...
#
#               type  lambda_arrival_rate
# 11   neighbourhood             5.954545
# 79   neighbourhood             3.818436
# 82   neighbourhood             2.423650
# 124  neighbourhood             2.248649
# 6    neighbourhood             1.526691
# ..             ...                  ...
# 149  neighbourhood                  NaN
# 150  neighbourhood                  NaN
# 155  neighbourhood                  NaN
# 156  neighbourhood                  NaN
# 157  neighbourhood                  NaN
#
# [158 rows x 4 columns]
