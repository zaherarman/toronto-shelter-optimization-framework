# %%
import os
os.chdir("..")
os.listdir()
# Out:
# ['pyproject.toml',
#  'README.md',
#  '.gitignore',
#  '.venv',
#  'poetry.lock',
#  '.git',
#  'data',
#  'notebooks',
#  'reports',
#  'src']

# %%
import gurobipy
from gurobipy import Model, GRB, quicksum


def build_model_multi_hotspot(
    H, # Set of hotspots
    S, # Set of shelters
    G, # Set of genders
    d_hg, # {(hotspot, gender): demand at hotspot h for gender g}
    c, # {shelter: capacity}
    dist, # {(hotspot, shelter): distance}
    e, # {(shelter, gender): 1 if eligible, 0 else}
):
    m = Model("Optimization_Multi_Hotspot")

    # Decision vars: x_hsg and z_hg
    x = {(h, s, g): m.addVar(vtype=GRB.INTEGER , lb=0.0, name=f"x_{h}_{s}_{g}") for h in H for s in S for g in G}
    
    z = {(h, g): m.addVar(vtype=GRB.INTEGER , lb=0.0, name=f"z_{h}_{g}") for h in H for g in G}

    # Good practice
    m.update()

    '''
    Demand balance for each hotspot. For every hotspot, the # of people sent to all shelters 
    plus the number of people left behind must equal the total demand for each hotspot
    '''
    # Now looping through G as well to balance demand for each gender
    for h in H:
        for g in G:
            m.addConstr(quicksum(x[(h, s, g)] for s in S) + z[(h, g)] == d_hg[(h, g)], name=f"demand_{h}_{g}")

    '''
    Capacity for each shelter. A shelter cannot accept more people than its capacity. Sum of people coming from
    all the hotspots to shelter s must be less than capacity c_s
    '''
    # We sum up all people (h) of all genders (g) arriving at shelter (s)
    for s in S:
        m.addConstr(quicksum(x[(h, s, g)] for h in H for g in G) <= c[s], name=f"cap_{s}")

    '''
    Eligibility constraints. If a shelter cannot accept a specific gender (e=0), 
    force the flow (x) to that shelter for that gender to be 0.
    '''
    for s in S:
        for g in G:
            if e[(s, g)] == 0:
                for h in H:
                    m.addConstr(x[(h, s, g)] == 0, name=f"elig_{s}_{g}_{h}")
# ---------------------------------------------------------
    # Step 1: Min total unsheltered
    # ---------------------------------------------------------
    m.setObjective(quicksum(z[(h, g)] for h in H for g in G), GRB.MINIMIZE)
    m.optimize()

    # Capture the Z value PER GENDER
    Z_star_per_gender = {}
    for g in G:
        Z_star_per_gender[g] = sum(z[(h, g)].X for h in H)

    # Total Z (just for reporting)
    Z_star_total = sum(Z_star_per_gender.values())

    # ---------------------------------------------------------
    # Step 2: Fix unsheltered PER GENDER and minimize distance
    # ---------------------------------------------------------
    
    # We add a constraint for EACH gender separately
    # "Men unserved must equal Stage 1 Men unserved"
    # "Women unserved must equal Stage 1 Women unserved"
    for g in G:
        m.addConstr(
            quicksum(z[(h, g)] for h in H) == Z_star_per_gender[g], 
            name=f"fix_unsheltered_{g}"
        )

    # Now minimize distance
    m.setObjective(quicksum(dist[(h, s)] * x[(h, s, g)] for h in H for s in S for g in G), GRB.MINIMIZE)
    m.optimize()

    return m, {"x": x, "z": z}, {"Z_star": Z_star_total, "obj_distance": m.ObjVal}

# %%
def run_referral_simulation(
    monthly_demands, hotspots, shelters, genders, 
    capacities, eligibility, distances, print_utilization=True
):
    results = []

    for month_idx, demand_data in enumerate(monthly_demands, start=1):
        
        # --- 1. PREPARE DATA ---
        demand_flat = {}
        total_monthly_demand = 0.0
        
        for h in hotspots:
            for g in genders:
                val = demand_data[h][g]
                demand_flat[(h, g)] = val
                total_monthly_demand += val

        # --- 2. RUN OPTIMIZATION ---
        model, variables, info = build_model_multi_hotspot(
            hotspots, shelters, genders, demand_flat, 
            capacities, distances, eligibility
        )
        
        if not variables: 
            print(f"Month {month_idx} Infeasible.")
            continue

        x_vars = variables["x"]
        z_vars = variables["z"]

        # --- 3. EXTRACT RESULTS ---
        total_assigned_count = 0.0
        for h in hotspots:
            for s in shelters:
                for g in genders:
                    total_assigned_count += x_vars[(h, s, g)].X

        # Overall Avg Distance
        avg_dist_month = 0.0
        if total_assigned_count > 0:
            avg_dist_month = info["obj_distance"] / total_assigned_count

        # --- 4. CALCULATE GENDER SPECIFIC STATS ---
        gender_stats = {}
        for g in genders:
            # 1. Count Unsheltered
            g_unsheltered = sum(z_vars[(h, g)].X for h in hotspots)
            
            # 2. Count Sheltered (Assigned)
            g_assigned = sum(x_vars[(h, s, g)].X for h in hotspots for s in shelters)
            
            # 3. Calculate Distance for this gender only
            g_total_dist = 0.0
            for h in hotspots:
                for s in shelters:
                    flow = x_vars[(h, s, g)].X
                    if flow > 0.001: # Optimization check for non-zero flow
                        g_total_dist += flow * distances[(h, s)]
            
            g_avg_dist = (g_total_dist / g_assigned) if g_assigned > 0 else 0.0

            gender_stats[g] = {
                "assigned": g_assigned,
                "unsheltered": g_unsheltered,
                "avg_dist": g_avg_dist
            }

        # --- 5. SHELTER UTILIZATION ---
        shelter_usage_stats = {}
        for s in shelters:
            used_amount = sum(x_vars[(h, s, g)].X for h in hotspots for g in genders)
            total_cap = capacities[s]
            pct_full = (used_amount / total_cap) * 100.0 if total_cap > 0 else 0.0
            
            shelter_usage_stats[s] = {
                "used": used_amount,
                "capacity": total_cap,
                "utilization_pct": pct_full,
            }

        # --- 6. PRINTING (Monthly Log) ---
        if print_utilization:
            print(f"\n{'='*40}")
            print(f"MONTH {month_idx}")
            print(f"{'='*40}")
            print(f"Total Demand: {total_monthly_demand:.0f}")
            print(f"Total Unserved: {info['Z_star']:.0f}")
            
            for g in genders:
                stats = gender_stats[g]
                print(f"  > {g.capitalize()}: Assigned {stats['assigned']:.0f} | Unserved {stats['unsheltered']:.0f} | Avg Dist {stats['avg_dist']:.3f} km")

        # Store Results
        month_result = {
            "month": month_idx,
            "total_unsheltered": info["Z_star"],
            "total_distance": info["obj_distance"],
            "total_assigned": total_assigned_count,
            "overall_avg_distance": avg_dist_month,
            "shelter_usage": shelter_usage_stats,
            "gender_breakdown": gender_stats # Contains the specific stats we need
        }
        results.append(month_result)

    return results

# %%
if __name__ == "__main__":
    import pandas as pd
    import sys
    # Assuming src.config is available in your environment
    # If running locally without the src module, replace PROCESSED_DATA_DIR with a string path like "."
    try:
        from src.config import PROCESSED_DATA_DIR
    except ImportError:
        from pathlib import Path
        PROCESSED_DATA_DIR = Path(".") # Fallback to current directory

    # ==========================================
    # 1. LOAD DATA FRAMES
    # ==========================================
    print("Loading Data...")
    df_demand = pd.read_csv(PROCESSED_DATA_DIR / 'demand_per_hotspot.csv')
    df_dist = pd.read_csv(PROCESSED_DATA_DIR / 'distance_amtrix.csv')
    df_capacity = pd.read_csv(PROCESSED_DATA_DIR / 'capacities_per_shelter.csv')
    df_genders = pd.read_csv(PROCESSED_DATA_DIR / "eligibility_df.csv")

    # ==========================================
    # 2. PROCESS DATAFRAMES INTO MODEL INPUTS
    # ==========================================
    
    print("Processing Data...")
    genders = ["men", "women"]
    
    # --- A. Define Hotspots ---
    # Hotspots are the columns in the distance matrix (excluding the name column)
    # Filter out any non-hotspot columns like 'Unnamed: 0' if they exist
    hotspots = [col for col in df_dist.columns if col != 'LOCATION_NAME' and not col.startswith('Unnamed')]

    # --- B. Process Shelters, Capacities & Eligibility ---
    shelters = []
    capacities = {}
    eligibility = {}
    
    # Map Location Name -> List of Shelter IDs 
    # (Critical because "Good Shepherd" appears multiple times with different IDs/Caps but one distance row)
    location_name_to_ids = {}

    # Iterate through capacities. We assume df_capacity and df_genders 
    # are sorted identically (row 0 in cap corresponds to row 0 in gender).
    for idx, row_cap in df_capacity.iterrows():
        # Use the DataFrame Index as the unique Shelter ID
        s_id = idx
        
        name = row_cap['SHELTER_NAME']
        cap = float(row_cap['CAPACITY'])
        
        # Get corresponding eligibility row by index
        row_elig = df_genders.iloc[idx] 
        
        # Verification: Ensure rows align by name
        if row_elig['SHELTER_NAME'] != name:
            # If they don't align, we try to find the matching row (safer)
            matching_rows = df_genders[df_genders['SHELTER_NAME'] == name]
            if not matching_rows.empty:
                row_elig = matching_rows.iloc[0]
            else:
                print(f"Warning: Could not find gender info for {name}")
                continue

        shelters.append(s_id)
        capacities[s_id] = cap
        
        # Extract Eligibility (1 or 0)
        eligibility[(s_id, "men")] = int(row_elig['men_eligible_eligible'])
        eligibility[(s_id, "women")] = int(row_elig['women_eligible_eligible'])
        
        # Build Map: Name -> [List of IDs]
        if name not in location_name_to_ids:
            location_name_to_ids[name] = []
        location_name_to_ids[name].append(s_id)

    # --- C. Process Distances ---
    distances = {}
    
    for idx, row in df_dist.iterrows():
        loc_name = row['LOCATION_NAME']
        
        # Check if this distance location exists in our shelter data
        if loc_name in location_name_to_ids:
            associated_ids = location_name_to_ids[loc_name]
            
            # Loop through all hotspots found in columns
            for h in hotspots:
                if h in df_dist.columns:
                    # Get distance value
                    dist_val = float(row[h])
                    
                    # Assign this distance to ALL unique shelter IDs that share this Location Name
                    for s_id in associated_ids:
                        distances[(h, s_id)] = dist_val

    # Failsafe: Fill missing distances with a high penalty
    # This happens if a shelter in the capacity file doesn't have a matching name in the distance file
    for h in hotspots:
        for s_id in shelters:
            if (h, s_id) not in distances:
                # print(f"Warning: Missing distance for {s_id} - {h}")
                distances[(h, s_id)] = 999.9 

    # --- D. Process Monthly Demand ---
    monthly_demands = []
    
    # Get sorted months (1 to 12)
    sorted_months = sorted(df_demand['month'].unique())
    
    for m in sorted_months:
        month_dict = {}
        # Filter dataframe for specific month
        df_m = df_demand[df_demand['month'] == m]
        
        for idx, row in df_m.iterrows():
            h = row['CFSAUID']
            
            # Only process if this hotspot exists in our defined hotspots list
            if h in hotspots:
                month_dict[h] = {
                    "men": float(row['male_from_hotspot']),
                    "women": float(row['female_from_hotspot'])
                }
        monthly_demands.append(month_dict)

    # ==========================================
    # 3. RUN SIMULATION
    # ==========================================
    print("\nStarting Simulation...")
    results = run_referral_simulation(
        monthly_demands=monthly_demands,
        hotspots=hotspots,
        shelters=shelters,
        genders=genders,
        capacities=capacities,
        eligibility=eligibility,
        distances=distances,
        print_utilization=True
    )

# ==========================================
    # 4. FINAL SUMMARY
    # ==========================================
    print("\n" + "="*100)
    print(f"{'YEARLY SUMMARY':^100}")
    print("="*100)
    
    # Header Row
    print(f"{'Month':<6} | {'TOTAL':<15} || {'MEN':<23} || {'WOMEN':<23}")
    print(f"{'':<6} | {'Unshelt':<7} {'AvgKM':<7} || {'Shelt':<6} {'Unshelt':<8} {'AvgKM':<7} || {'Shelt':<6} {'Unshelt':<8} {'AvgKM':<7}")
    print("-" * 100)

    for r in results:
        # Extract Total Stats
        tot_un = r['total_unsheltered']
        tot_dist = r['overall_avg_distance']
        
        # Extract Men Stats
        m_stats = r['gender_breakdown']['men']
        m_shelt = m_stats['assigned']
        m_un = m_stats['unsheltered']
        m_dist = m_stats['avg_dist']
        
        # Extract Women Stats
        w_stats = r['gender_breakdown']['women']
        w_shelt = w_stats['assigned']
        w_un = w_stats['unsheltered']
        w_dist = w_stats['avg_dist']

        print(
            f"{r['month']:<6} | "
            f"{tot_un:<7.0f} {tot_dist:<7.3f} || "
            f"{m_shelt:<6.0f} {m_un:<8.0f} {m_dist:<7.3f} || "
            f"{w_shelt:<6.0f} {w_un:<8.0f} {w_dist:<7.3f}"
        )
# Out:
# Loading Data...
# Processing Data...
#
# Starting Simulation...
# Restricted license - for non-production use only - expires 2027-11-29
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 967 rows, 1792 columns and 4432 nonzeros (Min)
# Model fingerprint: 0xe9ead36d
# Model has 32 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 8050.0000000
# Presolve removed 916 rows and 1216 columns
# Presolve time: 0.01s
# Presolved: 51 rows, 576 columns, 1136 nonzeros
# Found heuristic solution: objective 7292.0000000
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 5.535000e+03, 98 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5535.0000000 5535.00000  0.00%     -    0s
#
# Explored 1 nodes (98 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5535 7292 8050
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.535000000000e+03, best bound 5.535000000000e+03, gap 0.0000%
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 969 rows, 1792 columns and 4464 nonzeros (Min)
# Model fingerprint: 0x5593e4bc
# Model has 1760 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-02, 3e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+03]
#
# Loaded MIP start from previous solve with objective 20246.3
#
# Presolve removed 917 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 576 columns, 1152 nonzeros
# Found heuristic solution: objective 15197.267439
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 3.443652e+03, 59 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3443.6521534 3443.65215  0.00%     -    0s
#
# Explored 1 nodes (59 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3443.65 15197.3 20246.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.443652153416e+03, best bound 3.443652153416e+03, gap 0.0000%
#
# ========================================
# MONTH 1
# ========================================
# Total Demand: 8050
# Total Unserved: 5535
#   > Men: Assigned 1757 | Unserved 3716 | Avg Dist 1.214 km
#   > Women: Assigned 758 | Unserved 1819 | Avg Dist 1.728 km
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 967 rows, 1792 columns and 4432 nonzeros (Min)
# Model fingerprint: 0xde23edc9
# Model has 32 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 8086.0000000
# Presolve removed 916 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 576 columns, 1136 nonzeros
# Found heuristic solution: objective 7328.0000000
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 5.571000e+03, 92 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5571.0000000 5571.00000  0.00%     -    0s
#
# Explored 1 nodes (92 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5571 7328 8086
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.571000000000e+03, best bound 5.571000000000e+03, gap 0.0000%
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 969 rows, 1792 columns and 4464 nonzeros (Min)
# Model fingerprint: 0x4a7ce769
# Model has 1760 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-02, 3e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+03]
#
# Loaded MIP start from previous solve with objective 20246
#
# Presolve removed 917 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 576 columns, 1152 nonzeros
# Found heuristic solution: objective 15201.951485
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 3.441771e+03, 59 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3441.7712310 3441.77123  0.00%     -    0s
#
# Explored 1 nodes (59 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3441.77 15202 20246
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.441771230972e+03, best bound 3.441771230972e+03, gap 0.0000%
#
# ========================================
# MONTH 2
# ========================================
# Total Demand: 8086
# Total Unserved: 5571
#   > Men: Assigned 1757 | Unserved 3729 | Avg Dist 1.214 km
#   > Women: Assigned 758 | Unserved 1842 | Avg Dist 1.726 km
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 967 rows, 1792 columns and 4432 nonzeros (Min)
# Model fingerprint: 0x0373192a
# Model has 32 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 7580.0000000
# Presolve removed 916 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 576 columns, 1136 nonzeros
# Found heuristic solution: objective 6822.0000000
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 5.065000e+03, 102 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5065.0000000 5065.00000  0.00%     -    0s
#
# Explored 1 nodes (102 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5065 6822 7580
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.065000000000e+03, best bound 5.065000000000e+03, gap 0.0000%
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 969 rows, 1792 columns and 4464 nonzeros (Min)
# Model fingerprint: 0xfe30e18d
# Model has 1760 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-02, 3e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+03]
#
# Loaded MIP start from previous solve with objective 19141.9
#
# Presolve removed 917 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 576 columns, 1152 nonzeros
# Found heuristic solution: objective 15861.228719
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 3.467265e+03, 63 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3467.2649235 3467.26492  0.00%     -    0s
#
# Explored 1 nodes (63 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3467.26 15861.2 19141.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.467264923506e+03, best bound 3.467264923506e+03, gap 0.0000%
#
# ========================================
# MONTH 3
# ========================================
# Total Demand: 7580
# Total Unserved: 5065
#   > Men: Assigned 1757 | Unserved 3388 | Avg Dist 1.222 km
#   > Women: Assigned 758 | Unserved 1677 | Avg Dist 1.741 km
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 967 rows, 1792 columns and 4432 nonzeros (Min)
# Model fingerprint: 0x6aae6d98
# Model has 32 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 7594.0000000
# Presolve removed 916 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 576 columns, 1136 nonzeros
# Found heuristic solution: objective 6836.0000000
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 5.079000e+03, 110 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5079.0000000 5079.00000  0.00%     -    0s
#
# Explored 1 nodes (110 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5079 6836 7594
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.079000000000e+03, best bound 5.079000000000e+03, gap 0.0000%
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 969 rows, 1792 columns and 4464 nonzeros (Min)
# Model fingerprint: 0x94e4115a
# Model has 1760 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-02, 3e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+03]
#
# Loaded MIP start from previous solve with objective 19319.3
#
# Presolve removed 917 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 576 columns, 1152 nonzeros
# Found heuristic solution: objective 15912.596671
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 3.466562e+03, 63 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3466.5622405 3466.56224  0.00%     -    0s
#
# Explored 1 nodes (63 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3466.56 15912.6 19319.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.466562240536e+03, best bound 3.466562240536e+03, gap 0.0000%
#
# ========================================
# MONTH 4
# ========================================
# Total Demand: 7594
# Total Unserved: 5079
#   > Men: Assigned 1757 | Unserved 3371 | Avg Dist 1.223 km
#   > Women: Assigned 758 | Unserved 1708 | Avg Dist 1.739 km
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 967 rows, 1792 columns and 4432 nonzeros (Min)
# Model fingerprint: 0x98ff804f
# Model has 32 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 7195.0000000
# Presolve removed 916 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 576 columns, 1136 nonzeros
# Found heuristic solution: objective 6437.0000000
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 4.680000e+03, 102 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    4680.0000000 4680.00000  0.00%     -    0s
#
# Explored 1 nodes (102 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4680 6437 7195
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.680000000000e+03, best bound 4.680000000000e+03, gap 0.0000%
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 969 rows, 1792 columns and 4464 nonzeros (Min)
# Model fingerprint: 0x69b6ccbb
# Model has 1760 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-02, 3e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+03]
#
# Loaded MIP start from previous solve with objective 20119.2
#
# Presolve removed 917 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 576 columns, 1152 nonzeros
# Found heuristic solution: objective 16884.510149
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 3.487914e+03, 61 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3487.9144741 3487.91447  0.00%     -    0s
#
# Explored 1 nodes (61 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3487.91 16884.5 20119.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.487914474139e+03, best bound 3.487914474139e+03, gap 0.0000%
#
# ========================================
# MONTH 5
# ========================================
# Total Demand: 7195
# Total Unserved: 4680
#   > Men: Assigned 1757 | Unserved 3066 | Avg Dist 1.232 km
#   > Women: Assigned 758 | Unserved 1614 | Avg Dist 1.747 km
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 967 rows, 1792 columns and 4432 nonzeros (Min)
# Model fingerprint: 0x39e50fa4
# Model has 32 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 7041.0000000
# Presolve removed 916 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 576 columns, 1136 nonzeros
# Found heuristic solution: objective 6283.0000000
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 4.526000e+03, 105 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    4526.0000000 4526.00000  0.00%     -    0s
#
# Explored 1 nodes (105 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4526 6283 7041
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.526000000000e+03, best bound 4.526000000000e+03, gap 0.0000%
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 969 rows, 1792 columns and 4464 nonzeros (Min)
# Model fingerprint: 0xa4d47f11
# Model has 1760 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-02, 3e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+03]
#
# Loaded MIP start from previous solve with objective 20067.3
#
# Presolve removed 917 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 576 columns, 1152 nonzeros
# Found heuristic solution: objective 16845.668468
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 3.497568e+03, 63 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3497.5675025 3497.56750  0.00%     -    0s
#
# Explored 1 nodes (63 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3497.57 16845.7 20067.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.497567502494e+03, best bound 3.497567502494e+03, gap 0.0000%
#
# ========================================
# MONTH 6
# ========================================
# Total Demand: 7041
# Total Unserved: 4526
#   > Men: Assigned 1757 | Unserved 2939 | Avg Dist 1.235 km
#   > Women: Assigned 758 | Unserved 1587 | Avg Dist 1.750 km
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 967 rows, 1792 columns and 4432 nonzeros (Min)
# Model fingerprint: 0x13a88ddc
# Model has 32 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 6970.0000000
# Presolve removed 916 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 576 columns, 1136 nonzeros
# Found heuristic solution: objective 6212.0000000
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 4.455000e+03, 99 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    4455.0000000 4455.00000  0.00%     -    0s
#
# Explored 1 nodes (99 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4455 6212 6970
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.455000000000e+03, best bound 4.455000000000e+03, gap 0.0000%
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 969 rows, 1792 columns and 4464 nonzeros (Min)
# Model fingerprint: 0x75751aab
# Model has 1760 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-02, 3e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+03]
#
# Loaded MIP start from previous solve with objective 20017.6
#
# Presolve removed 917 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 576 columns, 1152 nonzeros
# Found heuristic solution: objective 16784.036103
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 3.500696e+03, 58 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3500.6964221 3500.69642  0.00%     -    0s
#
# Explored 1 nodes (58 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3500.7 16784 20017.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.500696422068e+03, best bound 3.500696422068e+03, gap 0.0000%
#
# ========================================
# MONTH 7
# ========================================
# Total Demand: 6970
# Total Unserved: 4455
#   > Men: Assigned 1757 | Unserved 2852 | Avg Dist 1.238 km
#   > Women: Assigned 758 | Unserved 1603 | Avg Dist 1.749 km
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 967 rows, 1792 columns and 4432 nonzeros (Min)
# Model fingerprint: 0xeec79e31
# Model has 32 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 6945.0000000
# Presolve removed 916 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 576 columns, 1136 nonzeros
# Found heuristic solution: objective 6187.0000000
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 4.430000e+03, 102 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    4430.0000000 4430.00000  0.00%     -    0s
#
# Explored 1 nodes (102 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4430 6187 6945
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.430000000000e+03, best bound 4.430000000000e+03, gap 0.0000%
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 969 rows, 1792 columns and 4464 nonzeros (Min)
# Model fingerprint: 0xfb97bba5
# Model has 1760 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-02, 3e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+03]
#
# Loaded MIP start from previous solve with objective 19994.8
#
# Presolve removed 917 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 576 columns, 1152 nonzeros
# Found heuristic solution: objective 16773.552028
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 3.502871e+03, 58 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3502.8711250 3502.87112  0.00%     -    0s
#
# Explored 1 nodes (58 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3502.87 16773.6 19994.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.502871124995e+03, best bound 3.502871124995e+03, gap 0.0000%
#
# ========================================
# MONTH 8
# ========================================
# Total Demand: 6945
# Total Unserved: 4430
#   > Men: Assigned 1757 | Unserved 2836 | Avg Dist 1.238 km
#   > Women: Assigned 758 | Unserved 1594 | Avg Dist 1.750 km
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 967 rows, 1792 columns and 4432 nonzeros (Min)
# Model fingerprint: 0x749d98dd
# Model has 32 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 6775.0000000
# Presolve removed 916 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 576 columns, 1136 nonzeros
# Found heuristic solution: objective 6017.0000000
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 4.260000e+03, 106 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    4260.0000000 4260.00000  0.00%     -    0s
#
# Explored 1 nodes (106 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4260 6017 6775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.260000000000e+03, best bound 4.260000000000e+03, gap 0.0000%
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 969 rows, 1792 columns and 4464 nonzeros (Min)
# Model fingerprint: 0x6fa5135c
# Model has 1760 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-02, 3e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+03]
#
# Loaded MIP start from previous solve with objective 19930.1
#
# Presolve removed 917 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 576 columns, 1152 nonzeros
# Found heuristic solution: objective 16743.999882
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 3.512490e+03, 58 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3512.4899218 3512.48992  0.00%     -    0s
#
# Explored 1 nodes (58 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3512.49 16744 19930.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.512489921832e+03, best bound 3.512489921832e+03, gap 0.0000%
#
# ========================================
# MONTH 9
# ========================================
# Total Demand: 6775
# Total Unserved: 4260
#   > Men: Assigned 1757 | Unserved 2732 | Avg Dist 1.242 km
#   > Women: Assigned 758 | Unserved 1528 | Avg Dist 1.756 km
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 967 rows, 1792 columns and 4432 nonzeros (Min)
# Model fingerprint: 0x86afa6aa
# Model has 32 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 6766.0000000
# Presolve removed 916 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 576 columns, 1136 nonzeros
# Found heuristic solution: objective 6008.0000000
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 4.251000e+03, 107 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    4251.0000000 4251.00000  0.00%     -    0s
#
# Explored 1 nodes (107 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4251 6008 6766
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.251000000000e+03, best bound 4.251000000000e+03, gap 0.0000%
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 969 rows, 1792 columns and 4464 nonzeros (Min)
# Model fingerprint: 0x28f3e8dc
# Model has 1760 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-02, 3e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+03]
#
# Loaded MIP start from previous solve with objective 19943
#
# Presolve removed 917 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 576 columns, 1152 nonzeros
# Found heuristic solution: objective 16745.357028
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 3.512674e+03, 70 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3512.6735955 3512.67360  0.00%     -    0s
#
# Explored 1 nodes (70 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3512.67 16745.4 19943
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.512673595479e+03, best bound 3.512673595479e+03, gap 0.0000%
#
# ========================================
# MONTH 10
# ========================================
# Total Demand: 6766
# Total Unserved: 4251
#   > Men: Assigned 1757 | Unserved 2705 | Avg Dist 1.242 km
#   > Women: Assigned 758 | Unserved 1546 | Avg Dist 1.754 km
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 967 rows, 1792 columns and 4432 nonzeros (Min)
# Model fingerprint: 0xddb443b9
# Model has 32 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+02]
# Found heuristic solution: objective 7055.0000000
# Presolve removed 916 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 576 columns, 1136 nonzeros
# Found heuristic solution: objective 6297.0000000
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 4.540000e+03, 100 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    4540.0000000 4540.00000  0.00%     -    0s
#
# Explored 1 nodes (100 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 4540 6297 7055
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.540000000000e+03, best bound 4.540000000000e+03, gap 0.0000%
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 969 rows, 1792 columns and 4464 nonzeros (Min)
# Model fingerprint: 0x565f128e
# Model has 1760 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-02, 3e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 3e+03]
#
# Loaded MIP start from previous solve with objective 20074.7
#
# Presolve removed 917 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 576 columns, 1152 nonzeros
# Found heuristic solution: objective 16841.526274
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 3.496129e+03, 63 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3496.1291110 3496.12911  0.00%     -    0s
#
# Explored 1 nodes (63 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3496.13 16841.5 20074.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.496129111049e+03, best bound 3.496129111049e+03, gap 0.0000%
#
# ========================================
# MONTH 11
# ========================================
# Total Demand: 7055
# Total Unserved: 4540
#   > Men: Assigned 1757 | Unserved 2934 | Avg Dist 1.235 km
#   > Women: Assigned 758 | Unserved 1606 | Avg Dist 1.749 km
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 967 rows, 1792 columns and 4432 nonzeros (Min)
# Model fingerprint: 0x614f3d29
# Model has 32 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 5e+02]
# Found heuristic solution: objective 8029.0000000
# Presolve removed 916 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 576 columns, 1136 nonzeros
# Found heuristic solution: objective 7271.0000000
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 5.514000e+03, 97 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5514.0000000 5514.00000  0.00%     -    0s
#
# Explored 1 nodes (97 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 5514 7271 8029
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.514000000000e+03, best bound 5.514000000000e+03, gap 0.0000%
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (mac64[arm] - Darwin 25.0.0 25A362)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 969 rows, 1792 columns and 4464 nonzeros (Min)
# Model fingerprint: 0x3f476032
# Model has 1760 linear objective coefficients
# Variable types: 0 continuous, 1792 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-02, 3e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+03]
#
# Loaded MIP start from previous solve with objective 20218.5
#
# Presolve removed 917 rows and 1216 columns
# Presolve time: 0.00s
# Presolved: 52 rows, 576 columns, 1152 nonzeros
# Found heuristic solution: objective 15169.439289
# Variable types: 0 continuous, 576 integer (32 binary)
#
# Root relaxation: objective 3.444642e+03, 59 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3444.6419241 3444.64192  0.00%     -    0s
#
# Explored 1 nodes (59 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3444.64 15169.4 20218.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.444641924112e+03, best bound 3.444641924112e+03, gap 0.0000%
#
# ========================================
# MONTH 12
# ========================================
# Total Demand: 8029
# Total Unserved: 5514
#   > Men: Assigned 1757 | Unserved 3690 | Avg Dist 1.215 km
#   > Women: Assigned 758 | Unserved 1824 | Avg Dist 1.728 km
#
# ====================================================================================================
#                                            YEARLY SUMMARY
# ====================================================================================================
# Month  | TOTAL           || MEN                     || WOMEN
#        | Unshelt AvgKM   || Shelt  Unshelt  AvgKM   || Shelt  Unshelt  AvgKM
# ----------------------------------------------------------------------------------------------------
# 1      | 5535    1.369   || 1757   3716     1.214   || 758    1819     1.728
# 2      | 5571    1.368   || 1757   3729     1.214   || 758    1842     1.726
# 3      | 5065    1.379   || 1757   3388     1.222   || 758    1677     1.741
# 4      | 5079    1.378   || 1757   3371     1.223   || 758    1708     1.739
# 5      | 4680    1.387   || 1757   3066     1.232   || 758    1614     1.747
# 6      | 4526    1.391   || 1757   2939     1.235   || 758    1587     1.750
# 7      | 4455    1.392   || 1757   2852     1.238   || 758    1603     1.749
# 8      | 4430    1.393   || 1757   2836     1.238   || 758    1594     1.750
# 9      | 4260    1.397   || 1757   2732     1.242   || 758    1528     1.756
# 10     | 4251    1.397   || 1757   2705     1.242   || 758    1546     1.754
# 11     | 4540    1.390   || 1757   2934     1.235   || 758    1606     1.749
# 12     | 5514    1.370   || 1757   3690     1.215   || 758    1824     1.728

# %% [markdown]
# #### Correct Sim Random Data

# %%
results = [
    {
        "month": 1,
        "total_unsheltered": 5535,
        "overall_avg_distance": 9.722,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 3716, "avg_dist": 11.062},
            "women": {"assigned": 758, "unsheltered": 1819, "avg_dist": 6.617}
        }
    },
    {
        "month": 2,
        "total_unsheltered": 5571,
        "overall_avg_distance": 7.968,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 3729, "avg_dist": 6.303},
            "women": {"assigned": 758, "unsheltered": 1842, "avg_dist": 11.827}
        }
    },
    {
        "month": 3,
        "total_unsheltered": 5065,
        "overall_avg_distance": 7.220,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 3388, "avg_dist": 6.957},
            "women": {"assigned": 758, "unsheltered": 1677, "avg_dist": 7.830}
        }
    },
    {
        "month": 4,
        "total_unsheltered": 5079,
        "overall_avg_distance": 7.545,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 3371, "avg_dist": 7.264},
            "women": {"assigned": 758, "unsheltered": 1708, "avg_dist": 8.197}
        }
    },
    {
        "month": 5,
        "total_unsheltered": 4680,
        "overall_avg_distance": 9.331,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 3066, "avg_dist": 9.922},
            "women": {"assigned": 758, "unsheltered": 1614, "avg_dist": 7.960}
        }
    },
    {
        "month": 6,
        "total_unsheltered": 4526,
        "overall_avg_distance": 7.645,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 2939, "avg_dist": 6.689},
            "women": {"assigned": 758, "unsheltered": 1587, "avg_dist": 9.861}
        }
    },
    {
        "month": 7,
        "total_unsheltered": 4455,
        "overall_avg_distance": 7.633,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 2852, "avg_dist": 7.406},
            "women": {"assigned": 758, "unsheltered": 1603, "avg_dist": 8.159}
        }
    },
    {
        "month": 8,
        "total_unsheltered": 4430,
        "overall_avg_distance": 9.650,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 2836, "avg_dist": 10.512},
            "women": {"assigned": 758, "unsheltered": 1594, "avg_dist": 7.653}
        }
    },
    {
        "month": 9,
        "total_unsheltered": 4260,
        "overall_avg_distance": 9.105,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 2732, "avg_dist": 8.915},
            "women": {"assigned": 758, "unsheltered": 1528, "avg_dist": 9.544}
        }
    },
    {
        "month": 10,
        "total_unsheltered": 4251,
        "overall_avg_distance": 9.316,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 2705, "avg_dist": 9.080},
            "women": {"assigned": 758, "unsheltered": 1546, "avg_dist": 9.864}
        }
    },
    {
        "month": 11,
        "total_unsheltered": 4540,
        "overall_avg_distance": 8.341,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 2934, "avg_dist": 7.603},
            "women": {"assigned": 758, "unsheltered": 1606, "avg_dist": 10.050}
        }
    },
    {
        "month": 12,
        "total_unsheltered": 5514,
        "overall_avg_distance": 8.288,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 3690, "avg_dist": 8.633},
            "women": {"assigned": 758, "unsheltered": 1824, "avg_dist": 7.488}
        }
    }
]

# ==========================================
# 4. FINAL SUMMARY
# ==========================================
print("\n" + "="*100)
print(f"{'YEARLY SUMMARY':^100}")
print("="*100)

# Header Row - Updated widths for MEN and WOMEN to 23 to match sub-columns
print(f"{'Month':<6} | {'TOTAL':<15} || {'MEN':<23} || {'WOMEN':<23}")
print(f"{'':<6} | {'Unshelt':<7} {'AvgKM':<7} || {'Shelt':<6} {'Unshelt':<8} {'AvgKM':<7} || {'Shelt':<6} {'Unshelt':<8} {'AvgKM':<7}")
print("-" * 100)

for r in results:
    # Extract Total Stats
    tot_un = r['total_unsheltered']
    tot_dist = r['overall_avg_distance']
    
    # Extract Men Stats
    m_stats = r['gender_breakdown']['men']
    m_shelt = m_stats['assigned']
    m_un = m_stats['unsheltered']
    m_dist = m_stats['avg_dist']
    
    # Extract Women Stats
    w_stats = r['gender_breakdown']['women']
    w_shelt = w_stats['assigned']
    w_un = w_stats['unsheltered']
    w_dist = w_stats['avg_dist']

    print(
        f"{r['month']:<6} | "
        f"{tot_un:<7.0f} {tot_dist:<7.3f} || "
        f"{m_shelt:<6.0f} {m_un:<8.0f} {m_dist:<7.3f} || "
        f"{w_shelt:<6.0f} {w_un:<8.0f} {w_dist:<7.3f}"
    )
# Out:
# ====================================================================================================
#                                            YEARLY SUMMARY
# ====================================================================================================
# Month  | TOTAL           || MEN                     || WOMEN
#        | Unshelt AvgKM   || Shelt  Unshelt  AvgKM   || Shelt  Unshelt  AvgKM
# ----------------------------------------------------------------------------------------------------
# 1      | 5535    9.722   || 1757   3716     11.062  || 758    1819     6.617
# 2      | 5571    7.968   || 1757   3729     6.303   || 758    1842     11.827
# 3      | 5065    7.220   || 1757   3388     6.957   || 758    1677     7.830
# 4      | 5079    7.545   || 1757   3371     7.264   || 758    1708     8.197
# 5      | 4680    9.331   || 1757   3066     9.922   || 758    1614     7.960
# 6      | 4526    7.645   || 1757   2939     6.689   || 758    1587     9.861
# 7      | 4455    7.633   || 1757   2852     7.406   || 758    1603     8.159
# 8      | 4430    9.650   || 1757   2836     10.512  || 758    1594     7.653
# 9      | 4260    9.105   || 1757   2732     8.915   || 758    1528     9.544
# 10     | 4251    9.316   || 1757   2705     9.080   || 758    1546     9.864
# 11     | 4540    8.341   || 1757   2934     7.603   || 758    1606     10.050
# 12     | 5514    8.288   || 1757   3690     8.633   || 758    1824     7.488

# %% [markdown]
# #### Correct Sim Greedy Data

# %%
results = [
    {
        "month": 1,
        "total_unsheltered": 5535,
        "overall_avg_distance": 6.063,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 3716, "avg_dist": 5.736},
            "women": {"assigned": 758, "unsheltered": 1819, "avg_dist": 6.819}
        }
    },
    {
        "month": 2,
        "total_unsheltered": 5571,
        "overall_avg_distance": 6.074,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 3729, "avg_dist": 5.744},
            "women": {"assigned": 758, "unsheltered": 1842, "avg_dist": 6.839}
        }
    },
    {
        "month": 3,
        "total_unsheltered": 5065,
        "overall_avg_distance": 5.672,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 3388, "avg_dist": 5.251},
            "women": {"assigned": 758, "unsheltered": 1677, "avg_dist": 6.649}
        }
    },
    {
        "month": 4,
        "total_unsheltered": 5079,
        "overall_avg_distance": 5.664,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 3371, "avg_dist": 5.218},
            "women": {"assigned": 758, "unsheltered": 1708, "avg_dist": 6.699}
        }
    },
    {
        "month": 5,
        "total_unsheltered": 4680,
        "overall_avg_distance": 5.496,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 3066, "avg_dist": 5.042},
            "women": {"assigned": 758, "unsheltered": 1614, "avg_dist": 6.546}
        }
    },
    {
        "month": 6,
        "total_unsheltered": 4526,
        "overall_avg_distance": 5.512,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 2939, "avg_dist": 5.075},
            "women": {"assigned": 758, "unsheltered": 1587, "avg_dist": 6.524}
        }
    },
    {
        "month": 7,
        "total_unsheltered": 4455,
        "overall_avg_distance": 5.537,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 2852, "avg_dist": 5.105},
            "women": {"assigned": 758, "unsheltered": 1603, "avg_dist": 6.539}
        }
    },
    {
        "month": 8,
        "total_unsheltered": 4430,
        "overall_avg_distance": 5.538,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 2836, "avg_dist": 5.110},
            "women": {"assigned": 758, "unsheltered": 1594, "avg_dist": 6.531}
        }
    },
    {
        "month": 9,
        "total_unsheltered": 4260,
        "overall_avg_distance": 5.488,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 2732, "avg_dist": 5.054},
            "women": {"assigned": 758, "unsheltered": 1528, "avg_dist": 6.494}
        }
    },
    {
        "month": 10,
        "total_unsheltered": 4251,
        "overall_avg_distance": 5.437,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 2705, "avg_dist": 4.979},
            "women": {"assigned": 758, "unsheltered": 1546, "avg_dist": 6.499}
        }
    },
    {
        "month": 11,
        "total_unsheltered": 4540,
        "overall_avg_distance": 5.513,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 2934, "avg_dist": 5.071},
            "women": {"assigned": 758, "unsheltered": 1606, "avg_dist": 6.538}
        }
    },
    {
        "month": 12,
        "total_unsheltered": 5514,
        "overall_avg_distance": 6.052,
        "gender_breakdown": {
            "men": {"assigned": 1757, "unsheltered": 3690, "avg_dist": 5.721},
            "women": {"assigned": 758, "unsheltered": 1824, "avg_dist": 6.819}
        }
    }
]

# ==========================================
# 4. FINAL SUMMARY
# ==========================================
print("\n" + "="*100)
print(f"{'YEARLY SUMMARY':^100}")
print("="*100)

# Header Row
print(f"{'Month':<6} | {'TOTAL':<15} || {'MEN':<23} || {'WOMEN':<23}")
print(f"{'':<6} | {'Unshelt':<7} {'AvgKM':<7} || {'Shelt':<6} {'Unshelt':<8} {'AvgKM':<7} || {'Shelt':<6} {'Unshelt':<8} {'AvgKM':<7}")
print("-" * 100)

for r in results:
    tot_un = r['total_unsheltered']
    tot_dist = r['overall_avg_distance']
    
    m_stats = r['gender_breakdown']['men']
    m_shelt = m_stats['assigned']
    m_un = m_stats['unsheltered']
    m_dist = m_stats['avg_dist']
    
    w_stats = r['gender_breakdown']['women']
    w_shelt = w_stats['assigned']
    w_un = w_stats['unsheltered']
    w_dist = w_stats['avg_dist']

    print(
        f"{r['month']:<6} | "
        f"{tot_un:<7.0f} {tot_dist:<7.3f} || "
        f"{m_shelt:<6.0f} {m_un:<8.0f} {m_dist:<7.3f} || "
        f"{w_shelt:<6.0f} {w_un:<8.0f} {w_dist:<7.3f}"
    )
# Out:
# ====================================================================================================
#                                            YEARLY SUMMARY
# ====================================================================================================
# Month  | TOTAL           || MEN                     || WOMEN
#        | Unshelt AvgKM   || Shelt  Unshelt  AvgKM   || Shelt  Unshelt  AvgKM
# ----------------------------------------------------------------------------------------------------
# 1      | 5535    6.063   || 1757   3716     5.736   || 758    1819     6.819
# 2      | 5571    6.074   || 1757   3729     5.744   || 758    1842     6.839
# 3      | 5065    5.672   || 1757   3388     5.251   || 758    1677     6.649
# 4      | 5079    5.664   || 1757   3371     5.218   || 758    1708     6.699
# 5      | 4680    5.496   || 1757   3066     5.042   || 758    1614     6.546
# 6      | 4526    5.512   || 1757   2939     5.075   || 758    1587     6.524
# 7      | 4455    5.537   || 1757   2852     5.105   || 758    1603     6.539
# 8      | 4430    5.538   || 1757   2836     5.110   || 758    1594     6.531
# 9      | 4260    5.488   || 1757   2732     5.054   || 758    1528     6.494
# 10     | 4251    5.437   || 1757   2705     4.979   || 758    1546     6.499
# 11     | 4540    5.513   || 1757   2934     5.071   || 758    1606     6.538
# 12     | 5514    6.052   || 1757   3690     5.721   || 758    1824     6.819
